# %% [markdown]
# ## Unit - 4
#
# ## Experiment No - 16
# ##  Basic charts and visual encoding
#
# ## Parth Dahiwade
# ## PRN - 25070123177
# ## ENTC - A3

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
data = {

        'Day': ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday' ],
        'Study_Hours': [4, 6, 3, 5,3.5],
        'Marks': [50, 60, 55, 70, 65],
        'Attendance':[60, 65, 70, 75, 80],
        'Sleep_Hours': [7, 8, 6, 9, 7] ,
        'Assignment_Completed': [10, 15, 12, 18, 1]
}
df = pd.DataFrame(data)
print(df)
# Out:
#          Day  Study_Hours  Marks  Attendance  Sleep_Hours  \
# 0     Monday          4.0     50          60            7
# 1    Tuesday          6.0     60          65            8
# 2  Wednesday          3.0     55          70            6
# 3   Thursday          5.0     70          75            9
# 4     Friday          3.5     65          80            7
#
#    Assignment_Completed
# 0                    10
# 1                    15
# 2                    12
# 3                    18
# 4                     1

# %%
# Line chart

plt.plot(df['Day'],df['Study_Hours'],marker='o')
plt.show()

# %%
#  Line chart

plt.plot(df['Day'],df['Study_Hours'],marker='o')
plt.title('Study Hours Over Days')
plt.xlabel('Day')
plt.ylabel('Study Hours')
# Out:
# Text(0, 0.5, 'Study Hours')

# %%
# Advanced Line Chart
plt.figure(figsize=(7,4))

plt.plot(df['Day'],df['Study_Hours'],marker='o',label='Study Hours')
plt.plot(df['Day'],df['Marks'],marker='o',label='Marks')

plt.title('Study Hours and Marks Trends')
plt.xlabel('Day')
plt.ylabel('Value')
plt.legend()
plt
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py'>

# %%
# Bar Chart

plt.bar(df['Day'],df['Study_Hours'],color='pink')
plt.title('Study Hours Over Days')
plt.xlabel('Day')
plt.ylabel('Study Hours')
plt.show()

# %%
# Compare study hours and marks

# Bar Chart

plt.bar(df['Study_Hours'],df['Marks'],color='pink')
plt.title('Marks over study hours')
plt.xlabel('Study_Hours')
plt.ylabel('Marks')
plt.show()

# %%
# Advanced Bar Graphs

bars = plt.bar(df['Day'],df['Study_Hours'],color='pink')
for bar in bars :
    y = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2,y,str(y),ha='center',va='bottom')
plt.title('Study Hours Over Days')
plt.xlabel('Day')
plt.ylabel('Study Hours')
plt.grid(axis='y')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Histogram (Distribution)

data = {
    'Marks':[50, 60, 55, 70, 65, 75, 80, 85, 90, 95, 68, 72, 77, 82, 88]

}

df = pd.DataFrame(data)
plt.hist(df['Marks'],bins=5,edgecolor='pink',alpha=0.30)
plt.title('Marks Distribution')
plt.xlabel('Marks')
plt.ylabel('Frequency')
plt.show()

# %%
# Scatter Plot (Relationship)

import matplotlib.pyplot as plt
import pandas as pd

data = {
        'Day': ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday' ],
        'Study_Hours': [4, 6, 3, 5,3.5],
        'Marks': [50, 60, 55, 70, 65],
        'Attendance':[60, 65, 70, 75, 80],
        'Sleep_Hours': [7, 8, 6, 9, 7] ,
        'Assignment_Completed': [10, 15, 12, 18, 1]
}
df = pd.DataFrame(data)

plt.scatter(df['Study_Hours'],df['Marks'])

plt.title('Study Hours vs Marks')
plt.xlabel('Study Hours')
plt.ylabel('Marks')
plt.show()

# %%
# Conditional scatter plot

df['Result'] = ['Fall','Pass','Fall','Pass','Pass']
colors = ['red' if r=='Fall' else 'green' for r in df['Result']]
plt.scatter(df['Study_Hours'],df['Marks'],c=colors)

plt.title('Study Hours vs Marks')
plt.xlabel('Study Hours')
plt.ylabel('Marks')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Line plot

sns.lineplot(x='Day',y='Study_Hours',data=df)
plt.title('Seaborn library plot')
plt.xlabel('Day')
plt.ylabel('Study Hours')
plt.show()

# %%
# Advanced Line Chart
plt.figure(figsize=(7,4))

plt.plot(df['Day'], df['Study_Hours'],
         marker='o', color='green', label='Study Hours')

plt.plot(df['Day'], df['Marks'],
         marker='s', color='red', label='Marks')

plt.title("Study Hours and Marks Trend")
plt.xlabel("Day")
plt.ylabel("Values")
plt.legend()
plt.show()

# %% [markdown]
# Common Color Options
#
# 🔹 Using names:
#
# 'blue'
#
# 'red'
#
# 'green'
#
# 'black'
#
# 'orange'
#
# 🔹 Short forms:
#
# 'b' → blue
#
# 'r' → red
#
# 'g' → green
#
# 'k' → black

# %%
#2. Bar Chart (Comparison)

plt.bar(df['Day'], df['Marks'], color='green')

plt.title("Marks Comparison")
plt.xlabel("Day")
plt.ylabel("Marks")

plt.show()

# %%
#Advanced Bar Graph
bars = plt.bar(df['Day'], df['Marks'], color='red')
for bar in bars:
    y = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, y, str(y),
             ha='center', va='bottom')

plt.title("Marks Comparison")
plt.xlabel("Day")
plt.ylabel("Marks")
plt.grid(axis='y')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(len(df['Day']))
width = 0.35

plt.bar(x - width/2, df['Study_Hours'], width, label='Study Hours')
plt.bar(x + width/2, df['Marks'], width, label='Marks')

plt.xticks(x, df['Day'])

plt.title("Study Hours vs Marks")
plt.xlabel("Day")
plt.ylabel("Values")
plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Example data (more values for better histogram)
marks = [50, 60, 55, 70, 65, 75, 80, 85, 90, 45, 68, 72, 77, 82, 88]

# Calculate mean
mean_value = np.mean(marks)

plt.figure(figsize=(7,4))

plt.hist(marks, bins=6, color='skyblue', edgecolor='black')

# Mean line
plt.axvline(mean_value, color='red', linestyle='--', linewidth=2, label='Mean')

plt.title("Advanced Histogram of Marks")
plt.xlabel("Marks")
plt.ylabel("Frequency")
plt.legend()

plt.grid(axis='y', linestyle='--', alpha=0.5)

plt.show()

# %%
#3.Histogram (Distribution)
#Shows how values are spread

data = {
    'Marks': [50, 60, 55, 70, 65, 75, 80, 85, 90, 45, 68, 72, 77, 82, 88]
}
df = pd.DataFrame(data)
plt.hist(df['Marks'], bins=5, edgecolor='black',alpha=0.30)
plt.title("Marks Distribution")
plt.xlabel("Marks")
plt.ylabel("Frequency")

plt.show()

# %% [markdown]
# 45 – 63
#
# 63 – 76
#
# 76 – 90

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = {
        'Day': ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday' ],
        'Study_Hours': [4, 6, 3, 5,3.5],
        'Marks': [50, 60, 55, 70, 65],
        'Attendance':[60, 65, 70, 75, 80],
        'Sleep_Hours': [7, 8, 6, 9, 7] ,
        'Assignment_Completed': [10, 15, 12, 18, 1]
}
df = pd.DataFrame(data)

plt.scatter(df['Study_Hours'], df['Marks'])

plt.title("Study Hours vs Marks")
plt.xlabel("Study Hours")
plt.ylabel("Marks")

plt.show()

# %%
# Conditional scatter plot
# Example category
df['Result'] = ['Fail','Pass','Fail','Pass','Pass']
colors = ['red' if r=='Fail' else 'green' for r in df['Result']]
plt.scatter(df['Study_Hours'], df['Marks'], c=colors)

plt.title("Study Hours vs Marks (Result-wise)")
plt.xlabel("Study Hours")
plt.ylabel("Marks")
plt.show()

# %%
# Dataset-2
data = {
    'Day': ['Mon','Tue','Wed','Thu','Fri','Sat','Sun','Mon','Tue','Wed'],
    'Region': ['North','South','East','West','North','South','East','West','North',
               'South'],
    'Sales': [200,220,250,270,300,350,400,280,260,290],
    'Profit': [20,25,30,35,50,60,80,40,38,45],
    'Customers': [30,35,40,45,50,65,80,55,48,52],
    'Category': ['Food','Clothing','Electronics','Food','Clothing','Electronics',
                 'Food','Clothing','Electronics','Food']
}

df = pd.DataFrame(data)
print(df)
# Out:
#    Day Region  Sales  Profit  Customers     Category
# 0  Mon  North    200      20         30         Food
# 1  Tue  South    220      25         35     Clothing
# 2  Wed   East    250      30         40  Electronics
# 3  Thu   West    270      35         45         Food
# 4  Fri  North    300      50         50     Clothing
# 5  Sat  South    350      60         65  Electronics
# 6  Sun   East    400      80         80         Food
# 7  Mon   West    280      40         55     Clothing
# 8  Tue  North    260      38         48  Electronics
# 9  Wed  South    290      45         52         Food

# %% [markdown]
# Same Graphs using Seaborn (Better Visualization)

# %%
#Line Plot
sns.lineplot(x='Day', y='Sales', data=df)
plt.title("Seaborn Line Plot")
plt.show()

# %%
#Bar Plot
sns.barplot(x='Days', y='Profit', data=df)
plt.title("Seaborn Bar Plot")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_6496/2337533014.py in <cell line: 0>()
#       1 #Bar Plot
# ----> 2 sns.barplot(x='Days', y='Profit', data=df)
#       3 plt.title("Seaborn Bar Plot")
#       4 plt.show()
#
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, seed, units, weights, orient, color, palette, saturation, fill, hue_norm, width, dodge, gap, log_scale, native_scale, formatter, legend, capsize, err_kws, ci, errcolor, errwidth, ax, **kwargs)
#    2339         estimator = "size"
#    2340
# -> 2341     p = _CategoricalAggPlotter(
#    2342         data=data,
#    2343         variables=dict(x=x, y=y, hue=hue, units=units, weight=weights),
#
# ...

# %%
#Histogram
sns.histplot(df['Sales'], bins=5)
plt.title("Seaborn Histogram")
plt.show()

# %%
#Scatter Plot
sns.scatterplot(x='Sales', y='Profit', data=df)
plt.title("Seaborn Scatter Plot")
plt.show()
